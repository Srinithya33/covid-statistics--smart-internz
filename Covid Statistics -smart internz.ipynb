# %%
import http.client

conn = http.client.HTTPSConnection("corona-virus-world-and-india-data.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "cb86e324b9mshc2bd0ab404860cbp1effbfjsne76dcf643c9b",
    'x-rapidapi-host': "corona-virus-world-and-india-data.p.rapidapi.com"
    }

conn.request("GET", "/api", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"countries_stat":[{"country_name":"USA","cases":"28,515,272","deaths":"504,826","region":"","total_recovered":"18,688,199","new_deaths":"2,278","new_cases":"61,450","serious_critical":"18,208","active_cases":"9,322,247","total_cases_per_1m_population":"85,830","deaths_per_1m_population":"1,520","total_tests":"341,369,911","tests_per_1m_population":"1,027,510"},{"country_name":"India","cases":"10,962,189","deaths":"156,123","region":"","total_recovered":"10,665,068","new_deaths":"85","new_cases":"12,643","serious_critical":"8,944","active_cases":"140,998","total_cases_per_1m_population":"7,895","deaths_per_1m_population":"112","total_tests":"208,703,791","tests_per_1m_population":"150,301"},{"country_name":"Brazil","cases":"10,030,626","deaths":"243,610","region":"","total_recovered":"8,995,246","new_deaths":"1,432","new_cases":"51,350","serious_critical":"8,318","active_cases":"791,770","total_cases_per_1m_population":"46,979","deaths_per_1m_population":"1,141","total_tests":"28,600
# ...

# %%
import requests

url = "https://corona-virus-world-and-india-data.p.rapidapi.com/api"

headers = {
    'x-rapidapi-key': "cb86e324b9mshc2bd0ab404860cbp1effbfjsne76dcf643c9b",
    'x-rapidapi-host': "corona-virus-world-and-india-data.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"countries_stat":[{"country_name":"USA","cases":"28,515,272","deaths":"504,826","region":"","total_recovered":"18,688,199","new_deaths":"2,278","new_cases":"61,450","serious_critical":"18,208","active_cases":"9,322,247","total_cases_per_1m_population":"85,830","deaths_per_1m_population":"1,520","total_tests":"341,369,911","tests_per_1m_population":"1,027,510"},{"country_name":"India","cases":"10,962,189","deaths":"156,123","region":"","total_recovered":"10,665,068","new_deaths":"85","new_cases":"12,643","serious_critical":"8,944","active_cases":"140,998","total_cases_per_1m_population":"7,895","deaths_per_1m_population":"112","total_tests":"208,703,791","tests_per_1m_population":"150,301"},{"country_name":"Brazil","cases":"10,030,626","deaths":"243,610","region":"","total_recovered":"8,995,246","new_deaths":"1,432","new_cases":"51,350","serious_critical":"8,318","active_cases":"791,770","total_cases_per_1m_population":"46,979","deaths_per_1m_population":"1,141","total_tests":"28,600
# ...

# %%
from flask import Flask ,request ,render_template

# %%
import numpy as np

# %%
import re
import requests

# %%
import json

# %%
import csv

# %%
import pandas as pd

# %%
## defining app
app =Flask(__name__)

# %%
## defining function output
def check(output):
    url = "https://corona-virus-world-and-india-data.p.rapidapi.com/api"
    querystring={"country": output}
    headers = {
    'x-rapidapi-key': "cb86e324b9mshc2bd0ab404860cbp1effbfjsne76dcf643c9b",
    'x-rapidapi-host': "corona-virus-world-and-india-data.p.rapidapi.com"
    }
    response = requests.request("GET", url, headers=headers)
    print(response.text)
    value=response.text
    output=json.loads(value)
    return response .json()

# %%
## rendering of home page
@app.route('/')
def home():
    return render_template('index.html')

##homepage with stats
@app.route('/stats')
def stats():
    return render_template('stats.html')

# %%
## statistics page
@app.route('/statistics',methods=['POST'])
def statistics():
    total=0
    output=request.form['country']
    print(output)
    essay=check(output)
    print(essay['data'])
    data_file=open(data_file.csv,'w')
    csv_writer=csv.writer(data_file)
    count=0
    for emp in essay['data']:
        print(emp)
        if count==0:
            ##writing headers of csv file
            header=['status','cases']
            csv_writer.writerow(header)
            count+=1
            
    ##writing data of csv file
    if(emp=="recovered" or emp=="deaths" or emp=="confirmed"):
        d=[emp,essay['data'][emp]]
        total=total+essay['data'][emp]
        print(d)
        csv_writer.writerow(d)
data_file.close()
df=pd.read_csv('data_file.csv')
temp =df.to_dict('records')
columnNames= df.columns.values
recovered = essay['data']['recovered'] * 100/total
deaths = essay ['data']['deaths'] * 100/total
confirmed =essay['data']['confirmed']*100/total

return render_template('result.html',essay=essay['data']['location'],records=temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-b2e43766f09c> in <module>
#      24         print(d)
#      25         csv_writer.writerow(d)
# ---> 26 data_file.close()
#      27 df=pd.read_csv('data_file.csv')
#      28 temp =df.to_dict('records')
#
# NameError: name 'data_file' is not defined

# %%
if __name__ == '__main__':
    app.run(debug=True)
